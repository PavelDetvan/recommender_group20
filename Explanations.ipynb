# %%
import pandas as pd

# Load the wines dataset
wines_df = pd.read_csv("All-XWines_Full_100K_wines_21M_ratings\XWines_Full_100K_wines.csv")
print("Wines DataFrame:")
print(wines_df.info())
print(wines_df.head())

# Load the ratings dataset
ratings_df = pd.read_csv("All-XWines_Full_100K_wines_21M_ratings\XWines_Full_21M_ratings.csv")
print("\nRatings DataFrame:")
print(ratings_df.info())
print(ratings_df.head())

# Merge wines and ratings dataframes
merged_df = pd.merge(ratings_df, wines_df, on='WineID')
# Out:
# Wines DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100646 entries, 0 to 100645
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   WineID      100646 non-null  int64
#  1   WineName    100646 non-null  object
#  2   Type        100646 non-null  object
#  3   Elaborate   100646 non-null  object
#  4   Grapes      100646 non-null  object
#  5   Harmonize   100646 non-null  object
#  6   ABV         100646 non-null  float64
#  7   Body        100646 non-null  object
#  8   Acidity     100646 non-null  object
#  9   Code        100646 non-null  object
#  10  Country     100646 non-null  object
#  11  RegionID    100646 non-null  int64
#  12  RegionName  100646 non-null  object
#  13  WineryID    100646 non-null  int64
#  14  WineryName  100646 non-null  object
#  15  Website     82779 non-null   object
#  16  Vintages    100646 non-null  object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 13.1+ MB
# None
#    WineID                         WineName       Type  \
# 0  100001               Espumante Moscatel  Sparkling
# 1  100002                       Ancellotta        Red
# 2  100003               Cabernet Sauvignon        Red
# 3  100004                   Virtus Moscato      White
# 4  100005  Maison de Ville Cabernet-Merlot        Red
#
#                        Elaborate                            Grapes  \
# 0                  Varietal/100%                ['Muscat/Moscato']
# 1                  Varietal/100%                    ['Ancellotta']
# 2                  Varietal/100%            ['Cabernet Sauvignon']
# 3                  Varietal/100%                ['Muscat/Moscato']
# 4  Assemblage/Bordeaux Red Blend  ['Cabernet Sauvignon', 'Merlot']
#
#                                            Harmonize   ABV           Body  \
# 0                 ['Pork', 'Rich Fish', 'Shellfish']   7.5  Medium-bodied
# 1  ['Beef', 'Barbecue', 'Codfish', 'Pasta', 'Pizz...  12.0  Medium-bodied
# 2                        ['Beef', 'Lamb', 'Poultry']  12.0    Full-bodied
# 3                                  ['Sweet Dessert']  12.0  Medium-bodied
# 4           ['Beef', 'Lamb', 'Game Meat', 'Poultry']  11.0    Full-bodied
#
#   Acidity Code Country  RegionID    RegionName  WineryID      WineryName  \
# 0    High   BR  Brazil      1001  Serra Gaúcha     10001     Casa Perini
# 1  Medium   BR  Brazil      1001  Serra Gaúcha     10001     Casa Perini
# 2    High   BR  Brazil      1001  Serra Gaúcha     10002    Castellamare
# 3  Medium   BR  Brazil      1001  Serra Gaúcha     10003  Monte Paschoal
# 4  Medium   BR  Brazil      1001  Serra Gaúcha     10000          Aurora
#
#                                   Website  \
# 0        http://www.vinicolaperini.com.br
# 1        http://www.vinicolaperini.com.br
# 2  https://www.emporiocastellamare.com.br
# 3         http://www.montepaschoal.com.br
# 4        http://www.vinicolaaurora.com.br
#
#                                             Vintages
# 0  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...
# 1  [2016, 2015, 2014, 2013, 2012, 2011, 2010, 200...
# 2  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 3  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# 4  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...
# C:\Users\yurim\AppData\Local\Temp\ipykernel_15096\683588102.py:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratings_df = pd.read_csv("All-XWines_Full_100K_wines_21M_ratings\XWines_Full_21M_ratings.csv")
# Ratings DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21013536 entries, 0 to 21013535
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   RatingID  int64
#  1   UserID    int64
#  2   WineID    int64
#  3   Vintage   object
#  4   Rating    float64
#  5   Date      object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 961.9+ MB
# None
#    RatingID   UserID  WineID Vintage  Rating                 Date
# 0         1  1604441  136103    1950     4.0  2019-10-14 11:20:52
# 1         2  1291483  136103    1950     5.0  2019-11-28 03:36:33
# 2         3  1070605  104036    1950     5.0  2017-12-28 10:15:55
# 3         4  1080181  144864    1950     5.0  2016-06-23 02:16:22
# 4         5  1834379  111430    1950     5.0  2021-05-16 17:58:14

# %%
def ExplainIndividual(user, wine):
    
    user_ratings = merged_df[merged_df["UserID"] == user] # Get the user's ratings
    wine_ratings = merged_df[merged_df["WineID"] == wine] # Get the wine's ratings
    user_wine_rating = user_ratings[user_ratings["WineID"] == wine] # Get the user's rating for the wine
    wine_details = wines_df[wines_df["WineID"] == wine] # Get the wine's details

    # Get the wine's average rating
    wine_avg_rating = wine_ratings["Rating"].mean()

    # Get the user's average rating
    user_avg_rating = user_ratings["Rating"].mean()

    # Get the user's average rating for wines with the same country
    user_country_avg_rating = user_ratings[user_ratings["Country"] == wine_details["Country"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same type
    user_type_avg_rating = user_ratings[user_ratings["Type"] == wine_details["Type"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same elaborate
    user_elaborate_avg_rating = user_ratings[user_ratings["Elaborate"] == wine_details["Elaborate"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same grapes
    user_grapes_avg_rating = user_ratings[user_ratings["Grapes"] == wine_details["Grapes"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same harmonize
    user_harmonize_avg_rating = user_ratings[user_ratings["Harmonize"] == wine_details["Harmonize"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same ABV interval
    abv_interval = 0.5
    wine_abv = wine_details["ABV"].values[0]
    user_abv_avg_rating = user_ratings[(user_ratings["ABV"] >= wine_abv - abv_interval) & (user_ratings["ABV"] <= wine_abv + abv_interval)]["Rating"].mean()

    # Get the user's average rating for wines with the same body
    user_body_avg_rating = user_ratings[user_ratings["Body"] == wine_details["Body"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same acidity
    user_acidity_avg_rating = user_ratings[user_ratings["Acidity"] == wine_details["Acidity"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same RegionName
    user_regionname_avg_rating = user_ratings[user_ratings["RegionName"] == wine_details["RegionName"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same WineryName
    user_wineryname_avg_rating = user_ratings[user_ratings["WineryName"] == wine_details["WineryName"].values[0]]["Rating"].mean()

    # Get the user's average rating for wines with the same Vintages
    user_vintages_avg_rating = user_ratings[user_ratings["Vintages"] == wine_details["Vintages"].values[0]]["Rating"].mean()

    # return the explanation 
    features_scores = [user_country_avg_rating, user_type_avg_rating, user_elaborate_avg_rating, user_grapes_avg_rating, user_harmonize_avg_rating, user_abv_avg_rating, user_body_avg_rating, user_acidity_avg_rating, user_regionname_avg_rating, user_wineryname_avg_rating, user_vintages_avg_rating]
    features_names = ["country", "type", "elaborate", "grapes", "harmonization", "ABV", "body", "acidity", "region", "winery", "vintage year"]

    explanation = ""

    if not user_wine_rating.empty:
        # if the user has liked the wine
        if user_wine_rating["Rating"].values[0] > user_avg_rating + user_ratings["Rating"].std():
            explanation += "You liked this wine! You rated it " + str(user_wine_rating["Rating"].values[0]) + " out of 5. You might also like this wine because "
        # if the wine is popular
        elif wine_avg_rating > 4.5:
            explanation += "This is a popular wine! It has an average rating of " + str(wine_avg_rating) + " out of 5. You might also like this wine because "
        else:
            explanation += "You might like this wine because "
    '''
    print("\nUser Average Rating: " + str(user_avg_rating))

    for i, features_score in enumerate(features_scores):
        if features_score > user_avg_rating:
            print(features_names[i] + ": Positive " + str(features_score))
        else:
            print(features_names[i] + ": Negative " + str(features_score))
    '''
    highest_two = sorted(range(len(features_scores)), key=lambda i: features_scores[i], reverse=True)[:2]
    explanation += "you have rated wines with the same " + features_names[highest_two[0]] + " and " + features_names[highest_two[1]] + " highly. \n"

    return explanation

# %%
def ExplainGroup(users, wine):
    # counters for majority voting
    feature_votes = {
        "Country": 0, "Type": 0, "Elaborate": 0, "Grapes": 0, "Harmonize": 0, 
        "ABV": 0, "Body": 0, "Acidity": 0, "RegionName": 0, "WineryName": 0, "Vintages": 0
    }

    for user in users:
        user_ratings = merged_df[merged_df["UserID"] == user]  # Get the user's ratings
        wine_details = wines_df[wines_df["WineID"] == wine]  # Get the wine's details


        user_avg_rating = user_ratings["Rating"].mean()
        user_rating_std = user_ratings["Rating"].std()

        # determine if the user likes the wine based on a feature
        def user_likes_feature(feature_avg_rating):
            return feature_avg_rating > user_avg_rating + user_rating_std

        # Get the user's average rating for wines with the same country
        user_country_avg_rating = user_ratings[user_ratings["Country"] == wine_details["Country"].values[0]]["Rating"].mean()
        if user_likes_feature(user_country_avg_rating):
            feature_votes["Country"] += 1

        # Get the user's average rating for wines with the same type
        user_type_avg_rating = user_ratings[user_ratings["Type"] == wine_details["Type"].values[0]]["Rating"].mean()
        if user_likes_feature(user_type_avg_rating):
            feature_votes["Type"] += 1

        # Get the user's average rating for wines with the same elaborate
        user_elaborate_avg_rating = user_ratings[user_ratings["Elaborate"] == wine_details["Elaborate"].values[0]]["Rating"].mean()
        if user_likes_feature(user_elaborate_avg_rating):
            feature_votes["Elaborate"] += 1

        # Get the user's average rating for wines with the same grapes
        user_grapes_avg_rating = user_ratings[user_ratings["Grapes"] == wine_details["Grapes"].values[0]]["Rating"].mean()
        if user_likes_feature(user_grapes_avg_rating):
            feature_votes["Grapes"] += 1

        # Get the user's average rating for wines with the same harmonize
        user_harmonize_avg_rating = user_ratings[user_ratings["Harmonize"] == wine_details["Harmonize"].values[0]]["Rating"].mean()
        if user_likes_feature(user_harmonize_avg_rating):
            feature_votes["Harmonize"] += 1

        # Get the user's average rating for wines with the same ABV interval
        abv_interval = 0.5
        wine_abv = wine_details["ABV"].values[0]
        user_abv_avg_rating = user_ratings[(user_ratings["ABV"] >= wine_abv - abv_interval) & (user_ratings["ABV"] <= wine_abv + abv_interval)]["Rating"].mean()
        if user_likes_feature(user_abv_avg_rating):
            feature_votes["ABV"] += 1

        # Get the user's average rating for wines with the same body
        user_body_avg_rating = user_ratings[user_ratings["Body"] == wine_details["Body"].values[0]]["Rating"].mean()
        if user_likes_feature(user_body_avg_rating):
            feature_votes["Body"] += 1

        # Get the user's average rating for wines with the same acidity
        user_acidity_avg_rating = user_ratings[user_ratings["Acidity"] == wine_details["Acidity"].values[0]]["Rating"].mean()
        if user_likes_feature(user_acidity_avg_rating):
            feature_votes["Acidity"] += 1

        # Get the user's average rating for wines with the same RegionName
        user_regionname_avg_rating = user_ratings[user_ratings["RegionName"] == wine_details["RegionName"].values[0]]["Rating"].mean()
        if user_likes_feature(user_regionname_avg_rating):
            feature_votes["RegionName"] += 1

        # Get the user's average rating for wines with the same WineryName
        user_wineryname_avg_rating = user_ratings[user_ratings["WineryName"] == wine_details["WineryName"].values[0]]["Rating"].mean()
        if user_likes_feature(user_wineryname_avg_rating):
            feature_votes["WineryName"] += 1

        # Get the user's average rating for wines with the same Vintages
        user_vintages_avg_rating = user_ratings[user_ratings["Vintages"] == wine_details["Vintages"].values[0]]["Rating"].mean()
        if user_likes_feature(user_vintages_avg_rating):
            feature_votes["Vintages"] += 1

    explanation = "Group likes the wine based on:"

    print(feature_votes)

    # Determine the majority vote for each feature
    majority_threshold = len(users) / 2
    for feature, votes in feature_votes.items():
        if votes > majority_threshold:
            explanation += f" {feature},"

    explanation = explanation[:-1] + "."
    return explanation

# %%
users = [1209683, 1209684, 1209685]
wine = 111558

if len(users) == 1:
    print(ExplainIndividual(users[0], wine))
else:
    print(ExplainGroup(users, wine))
# Out:
# {'Country': 0, 'Type': 0, 'Elaborate': 0, 'Grapes': 0, 'Harmonize': 0, 'ABV': 0, 'Body': 0, 'Acidity': 0, 'RegionName': 0, 'WineryName': 0, 'Vintages': 1}
# Group likes the wine based on.
